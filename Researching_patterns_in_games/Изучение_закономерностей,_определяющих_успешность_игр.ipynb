# %% [markdown]
# # Проект. Изучение закономерностей, определяющих успешность игр.

# %% [markdown]
# # Оглавление
# * 0. [Описание](#description)
#    - 0.1.[Описание проекта](#project_description)
#    - 0.2.[Описание данных](#data_description)
#    - 0.3.[Чек-лист готовности проекта](#check_list)
#
# * 1. [Шаг 1.Открытие файла с данными и изучение общей информации](#step1)
#    - 1.1[Признак Name](#Name)
#    - 1.2.[Признак Platform](#Platform)
#    - 1.3.[Признак Year_of_Release](#Year_of_Release)
#    - 1.4.[Признак Genre](#Genre)
#    - 1.5.[Признак NA_sales](#NA_sales)
#    - 1.6.[Признак EU_sales ](#EU_sales)
#    - 1.7.[Признак JP_sales](#JP_sales)
#    - 1.8.[Признак Other_sales](#Other_sales)
#    - 1.9.[Признак Critic_Score](#Critic_Score)
#    - 1.10.[Признак User_Score](#User_Score)
#    - 1.11.[Признак Rating](#Rating)
#    - 1.12.[Вывод по шагу 1](#step1_conclusion)
#
# * 2. [Шаг 2. Предобработка данных для признаков](#step2)
#    - 2.1.[Изменение названий признаков](#change_feature_name)
#    - 2.2.[Замена пропущенных значений](#сhange_nan)
#       + 2.2.1.[Удаление полпустых строк](#drop_half-empty_lines)
#       + 2.2.2.[Замена пропущенных значений для признака critic score](#change_nan_critic_score)
#       + 2.2.3.[Замена типа данных для признака critic_score](#change_data_type_critic_score)
#       + 2.2.4.[Замена пропущенных значений для признака user_score](#change_nan_user_score)
#       + 2.2.5.[Замена типа данных для признака user_score](#change_data_type_user_score)
#       + 2.2.6.[Замена пропущенных значений для признака rating](#change_nan_rating)
#       + 2.2.7.[Замена пропущенных значений для признака year_of_release](#change_nan_year_of_release)
#       + 2.2.8.[Замена типа данных для признака year_of_release](#change_data_type_year_of_release)
#       + 2.2.9[Расчет нового признака и добавление в таблицу](#add_feature)
#    - 2.3.[Вывод по шагу 2](#step2_conclusion)
#
# * 3. [Шаг 3. Исследовательский анализ данных](#step3)
#     - 3.1.[Нахождение количества игр по разным годам.](#3.1)
#     - 3.2.[Построение распределения продаж по платформам](#3.2)
#         + 3.2.1.[Платформа PS2](#PS2)
#         + 3.2.2.[Платформа X360](#X360)
#         + 3.2.3.[Платформа PS3](#PS3)
#         + 3.2.4.[Платформа Wii](#Wii)
#         + 3.2.5.[Платформа DS](#DS)
#         + 3.2.6.[Платформа PS](#PS)
#         + 3.2.7.[Платформа GBA](#GBA)
#     - 3.3.[Построение распределения продаж по платформам за актуальный период](#3.3)
#     - 3.4.[Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.](#3.4)
#     - 3.5.[Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.](#3.5)
#     - 3.6.[Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?](#3.6)
#
# * 4. [Шаг 4. Портреты пользователя каждого региона](#step4)
#     - 4.1.[Самые популярные платформы (топ-5). Опишите различия в долях продаж.](#4.1)
#     - 4.2.[Самые популярные жанры (топ-5). Поясните разницу.](#4.2)
#     - 4.3.[Влияет ли рейтинг ESRB на продажи в отдельном регионе?](#4.3)
#
# * 5. [Шаг 5. Проверка гипотез](#step5)
#     - 5.1.[Гипотеза: 'средние пользовательские рейтинги платформ Xbox One и PC одинаковые;'](#h_1)
#     - 5.2.[Гипотеза: 'средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.'](#h_2)
#
# * 6. [Шаг 6. Общий вывод](#step6)

# %% [markdown]
# ## Описание<a name="description"></a>

# %% [markdown]
# ### Описание проекта<a name="project_description"></a>

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры.
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation).
# **Вам нужно** выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура **ESRB** (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# ### Описание данных <a name="data_description"></a>

# %% [markdown]
# **Name** — название игры
# **Platform** — платформа
# **Year_of_Release** — год выпуска
# **Genre** — жанр игры
# **NA_sales** — продажи в Северной Америке (миллионы проданных копий)
# **EU_sales** — продажи в Европе (миллионы проданных копий)
# **JP_sales** — продажи в Японии (миллионы проданных копий)
# **Other_sales** — продажи в других странах (миллионы проданных копий)
# **Critic_Score** — оценка критиков (максимум 100)
# **User_Score** — оценка пользователей (максимум 10)
# **Rating** — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# ## Шаг 1. Открытие файла с данными и изучение общей информации <a name="step1"></a>

# %%
#библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('games.csv')

# %%
display(data.head())
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.describe().T
# Out:
#                    count         mean        std     min     25%      50%  \
# Year_of_Release  16446.0  2006.484616   5.877050  1980.0  2003.0  2007.00
# NA_sales         16715.0     0.263377   0.813604     0.0     0.0     0.08
# EU_sales         16715.0     0.145060   0.503339     0.0     0.0     0.02
# JP_sales         16715.0     0.077617   0.308853     0.0     0.0     0.00
# Other_sales      16715.0     0.047342   0.186731     0.0     0.0     0.01
# Critic_Score      8137.0    68.967679  13.938165    13.0    60.0    71.00
#
#                      75%      max
# Year_of_Release  2010.00  2016.00
# NA_sales            0.24    41.36
# EU_sales            0.11    28.96
# JP_sales            0.04    10.22
# Other_sales         0.03    10.57
# Critic_Score       79.00    98.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
#функция для расчета процента пропущенных значений по признаку
def missing_percent(dataset):
    percent=167.15
    isnull=dataset.isnull().sum()
    if isnull==0:
        print('Процент пропущенных значений: 0%, количество пропущенных значений в выборке: 0.')
    else: 
        missing=(dataset.isnull().sum()/percent)/100
        return  print('Процент пропущенных значений: {:.2%}'.format(missing),',','количество пропущенных значений в выборке: {}. '.format(isnull))

# %% [markdown]
# ##### 1. Признак **Name** <a name="Name"></a>

# %% [markdown]
# В признаке **'Name'** указан правильный тип данных.

# %%
data['Name'].describe().T
# Out:
# count                           16713
# unique                          11559
# top       Need for Speed: Most Wanted
# freq                               12
# Name: Name, dtype: object

# %%
missing_percent(data['Name'])
# Out:
# Процент пропущенных значений: 0.01% , количество пропущенных значений в выборке: 2.

# %%
data['Name'].isnull().sort_values(ascending = False)
# Out:
# 14244     True
# 659       True
# 16714    False
# 5573     False
# 5568     False
#          ...
# 11137    False
# 11136    False
# 11135    False
# 11134    False
# 0        False
# Name: Name, Length: 16715, dtype: bool

# %%
#посмотрю, что за строки с пропущенными значениями, так как их всего 2
display(data.loc[[14244]])
display(data.loc[[659]])
# Out:
#       Name Platform  Year_of_Release Genre  NA_sales  EU_sales  JP_sales  \
# 14244  NaN      GEN           1993.0   NaN       0.0       0.0      0.03
#
#        Other_sales  Critic_Score User_Score Rating
# 14244          0.0           NaN        NaN    NaN
#     Name Platform  Year_of_Release Genre  NA_sales  EU_sales  JP_sales  \
# 659  NaN      GEN           1993.0   NaN      1.78      0.53       0.0
#
#      Other_sales  Critic_Score User_Score Rating
# 659         0.08           NaN        NaN    NaN

# %% [markdown]
# ##### Промежуточный вывод по признаку Name:
# **Необходимо:**
# * подумать над удалением этих строк, так как значительная часть данных потеряна

# %% [markdown]
# ##### 2. Признак **Platform** <a name="Platform"></a>

# %% [markdown]
# В признаке **'Platform'** указан правильный тип данных.

# %%
data['Platform'].describe().T
# Out:
# count     16715
# unique       31
# top         PS2
# freq       2161
# Name: Platform, dtype: object

# %%
missing_percent(data['Platform'])
# Out:
# Процент пропущенных значений: 0%, количество пропущенных значений в выборке: 0.

# %%
display(data['Platform'].unique())
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# ##### Промежуточный вывод по признаку Platform:
#
# В данном признаке все в порядке: пропущенных значений нет, одинаковых названий платформ, но с разным написанием нет.

# %% [markdown]
# ##### 3. Признак **Year_of_Release** <a name="Year_of_Release"></a>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data['Year_of_Release'].describe().T
# Out:
# count    16446.000000
# mean      2006.484616
# std          5.877050
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: Year_of_Release, dtype: float64

# %%
missing_percent(data['Year_of_Release'])
# Out:
# Процент пропущенных значений: 1.61% , количество пропущенных значений в выборке: 269.

# %%
data.query('Year_of_Release=="nan"')
# Out:
#                                     Name Platform  Year_of_Release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# Сейчас хочу посмотреть на выборку по разным названиям игр.

# %%
data.query('Name=="Madden NFL 2004"')
# Out:
#                  Name Platform  Year_of_Release   Genre  NA_sales  EU_sales  \
# 183   Madden NFL 2004      PS2              NaN  Sports      4.26      0.26
# 1881  Madden NFL 2004       XB           2003.0  Sports      1.02      0.02
# 3889  Madden NFL 2004       GC           2003.0  Sports      0.40      0.10
# 5708  Madden NFL 2004      GBA           2003.0  Sports      0.22      0.08
#
#       JP_sales  Other_sales  Critic_Score User_Score Rating
# 183       0.01         0.71          94.0        8.5      E
# 1881      0.00         0.05          92.0        8.3      E
# 3889      0.00         0.01          94.0        7.7      E
# 5708      0.00         0.01          70.0        6.6      E

# %% [markdown]
# Могу заметить, что на других платформах указан год релиза, а у **PS2** нет.

# %%
data.query('Name=="Space Invaders"')
# Out:
#                  Name Platform  Year_of_Release    Genre  NA_sales  EU_sales  \
# 609    Space Invaders     2600              NaN  Shooter      2.36      0.14
# 4264   Space Invaders     SNES           1994.0  Shooter      0.00      0.00
# 8580   Space Invaders      N64           1999.0  Shooter      0.13      0.03
# 10383  Space Invaders      GBA           2002.0  Shooter      0.08      0.03
#
#        JP_sales  Other_sales  Critic_Score User_Score Rating
# 609        0.00         0.03           NaN        NaN    NaN
# 4264       0.46         0.00           NaN        NaN    NaN
# 8580       0.00         0.00           NaN        NaN    NaN
# 10383      0.00         0.00           NaN        NaN    NaN

# %% [markdown]
# Здесь отсутсвует год релиза по для платформы **2600**.

# %%
data.query('Name=="LEGO Batman: The Videogame"')
# Out:
#                              Name Platform  Year_of_Release   Genre  NA_sales  \
# 397    LEGO Batman: The Videogame     X360           2008.0  Action      2.04
# 456    LEGO Batman: The Videogame      Wii              NaN  Action      1.80
# 460    LEGO Batman: The Videogame       DS           2008.0  Action      1.75
# 1519   LEGO Batman: The Videogame      PS3           2008.0  Action      0.72
# 1538   LEGO Batman: The Videogame      PSP              NaN  Action      0.57
# 1553   LEGO Batman: The Videogame      PS2           2008.0  Action      0.72
# 12465  LEGO Batman: The Videogame       PC           2008.0  Action      0.02
#
#        EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 397        1.02       0.0         0.32          76.0        7.9   E10+
# 456        0.97       0.0         0.29          74.0        7.9   E10+
# 460        1.01       0.0         0.29          72.0          8   E10+
# ...

# %% [markdown]
# Года релиза нет для платформ **Wii** и **PSP**.

# %% [markdown]
# Для разных игр, отсутствует год релиза по разным платформам. Можно заменить пропущенные значения средними значениями для разных выборок игр.

# %% [markdown]
# ##### Промежуточный вывод по признаку Year_of_Release:
# **Необходимо:**
# * поменять тип данных **float64** на **int64**
# * заменить пропущенные значения на среднее в выборках игр

# %% [markdown]
# ##### 4. Признак **Genre** <a name="Genre"></a>

# %%
data['Genre'].describe().T
# Out:
# count      16713
# unique        12
# top       Action
# freq        3369
# Name: Genre, dtype: object

# %%
data['Genre'].value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
missing_percent(data['Genre'])
# Out:
# Процент пропущенных значений: 0.01% , количество пропущенных значений в выборке: 2.

# %%
data['Genre'].isnull().sort_values(ascending = False)
# Out:
# 14244     True
# 659       True
# 16714    False
# 5573     False
# 5568     False
#          ...
# 11137    False
# 11136    False
# 11135    False
# 11134    False
# 0        False
# Name: Genre, Length: 16715, dtype: bool

# %%
display(data.loc[[14244]])
display(data.loc[[659]])
# Out:
#       Name Platform  Year_of_Release Genre  NA_sales  EU_sales  JP_sales  \
# 14244  NaN      GEN           1993.0   NaN       0.0       0.0      0.03
#
#        Other_sales  Critic_Score User_Score Rating
# 14244          0.0           NaN        NaN    NaN
#     Name Platform  Year_of_Release Genre  NA_sales  EU_sales  JP_sales  \
# 659  NaN      GEN           1993.0   NaN      1.78      0.53       0.0
#
#      Other_sales  Critic_Score User_Score Rating
# 659         0.08           NaN        NaN    NaN

# %% [markdown]
# Данные не информативны в этих строках, скорее всего придется удалить две строки из выборки.

# %% [markdown]
# ##### Промежуточный вывод по признаку Genre:
# **Необходимо:**
# * удалить две строки из выборки, у которых пропущенные значения не только по признаку **Genre**, но и по большинству остальных признаков.

# %% [markdown]
# ##### 5. Признак **NA_sales** <a name="NA_sales"></a>

# %%
data['NA_sales'].describe().T
# Out:
# count    16715.000000
# mean         0.263377
# std          0.813604
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.240000
# max         41.360000
# Name: NA_sales, dtype: float64

# %%
missing_percent(data['NA_sales'])
# Out:
# Процент пропущенных значений: 0%, количество пропущенных значений в выборке: 0.

# %% [markdown]
# ##### Промежуточный вывод по признаку NA_sales:
# На первый взгляд проблем не было выявлено

# %% [markdown]
# ##### 6. Признак **EU_sales** <a name="EU_sales"></a>

# %%
data['EU_sales'].describe().T
# Out:
# count    16715.000000
# mean         0.145060
# std          0.503339
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.110000
# max         28.960000
# Name: EU_sales, dtype: float64

# %%
missing_percent(data['EU_sales'])
# Out:
# Процент пропущенных значений: 0%, количество пропущенных значений в выборке: 0.

# %% [markdown]
# ##### Промежуточный вывод по признаку EU_sales:
# На первый взгляд проблем не было выявлено

# %% [markdown]
# ##### 7. Признак **JP_sales** <a name="JP_sales"></a>

# %%
data['JP_sales'].describe().T
# Out:
# count    16715.000000
# mean         0.077617
# std          0.308853
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: JP_sales, dtype: float64

# %%
missing_percent(data['JP_sales'])
# Out:
# Процент пропущенных значений: 0%, количество пропущенных значений в выборке: 0.

# %% [markdown]
# ##### Промежуточный вывод по признаку JP_sales:
# На первый взгляд проблем не было выявлено

# %% [markdown]
# ##### 8. Признак **Other_sales** <a name="Other_sales"></a>

# %%
data['Other_sales'].describe().T
# Out:
# count    16715.000000
# mean         0.047342
# std          0.186731
# min          0.000000
# 25%          0.000000
# 50%          0.010000
# 75%          0.030000
# max         10.570000
# Name: Other_sales, dtype: float64

# %%
missing_percent(data['Other_sales'])
# Out:
# Процент пропущенных значений: 0%, количество пропущенных значений в выборке: 0.

# %% [markdown]
# ##### Промежуточный вывод по признаку Other_sales:
# На первый взгляд проблем не было выявлено

# %% [markdown]
# ##### 9. Признак **Critic_Score** <a name="Critic_Score"></a>

# %%
data['Critic_Score'].describe().T
# Out:
# count    8137.000000
# mean       68.967679
# std        13.938165
# min        13.000000
# 25%        60.000000
# 50%        71.000000
# 75%        79.000000
# max        98.000000
# Name: Critic_Score, dtype: float64

# %%
missing_percent(data['Critic_Score'])
# Out:
# Процент пропущенных значений: 51.32% , количество пропущенных значений в выборке: 8578.

# %%
data['Critic_Score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])

# %% [markdown]
# Скорее всего пропуски образовались по той причине, что игры не популярны или же во время релиза игр не было принято давать оценку играм (аналогично для User_Score и Raiting).
# Заменять пропущенные значения я буду 0.

# %% [markdown]
# ##### Промежуточный вывод по признаку Critic_Score:
# **Необходимо:**
# * заменить пропущенные значения на 0

# %% [markdown]
# ##### 10. Признак **User_Score** <a name="User_Score"></a>

# %%
data['User_Score'].describe().T
# Out:
# count     10014
# unique       96
# top         tbd
# freq       2424
# Name: User_Score, dtype: object

# %%
display(data['User_Score'].unique())
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
missing_percent(data['User_Score'])
# Out:
# Процент пропущенных значений: 40.09% , количество пропущенных значений в выборке: 6701.

# %% [markdown]
# **tbd**-будет определено или будет определено: используется, когда что-то еще не решено или еще не известно.

# %% [markdown]
# ##### Промежуточный вывод по признаку User_Score:
# * заменить пропущенные значения на **-1**, а **tbd** на **-2**
# * заменить тип данных object на float64

# %% [markdown]
# ##### 11. Признак **Rating** <a name="Rating"></a>

# %%
data['Rating'].describe().T
# Out:
# count     9949
# unique       8
# top          E
# freq      3990
# Name: Rating, dtype: object

# %%
data['Rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
missing_percent(data['Rating'])
# Out:
# Процент пропущенных значений: 40.48% , количество пропущенных значений в выборке: 6766.

# %% [markdown]
# ##### Промежуточный вывод по признаку Rating:
# **Необходимо:**
# * заменить пропущенные значения на пустые строки;
# * заменить RP на пустые строки

# %% [markdown]
# ## Вывод по шагу 1. <a name="step1_conclusion"></a>

# %% [markdown]
# В ходе изучения файла и его прочтения стало ясно, что таблица содержит в себе 11 признаков на 16715 строк.

# %% [markdown]
# **Были выявлены пропущенные значения.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
missing_values = pd.DataFrame(data.isna().sum(),columns=['Количество пропущенных значений'])

# %%
missing_values = missing_values.rename_axis(missing_values.index.name, axis=1).rename_axis('Признак')

# %%
percent=167.15
missing_values['Процент пропущеннх значений(%)']=(missing_values['Количество пропущенных значений']/percent)

# %%
(missing_values


 .style

 .set_caption('Таблица 1. Пропущенные значения')
 
 .background_gradient(cmap='Reds', axis=0)
)
# Out:
# <style  type="text/css" >
#     #T_7dc7a7c8_d842_11ec_b3ba_98460a9f726erow0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7dc7a7c8_d842_11ec_b3ba_98460a9f726erow0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7dc7a7c8_d842_11ec_b3ba_98460a9f726erow1_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7dc7a7c8_d842_11ec_b3ba_98460a9f726erow1_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7dc7a7c8_d842_11ec_b3ba_98460a9f726erow2_col0 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_7dc7a7c8_d842_11ec_b3ba_98460a9f726erow2_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_7dc7a7c8_d842_11ec_b3ba_98460a9f726erow3_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
# ...

# %%
conclusion = pd.DataFrame([["Name","0.01%","удаление 2 строк с пропусками в практически во всех признаках","object","-"],
                               ["Platform","-","-","object","-"],
                               ["Year_of_Release","1.61%","заменить пропуски средними значениями для разных выборок игр","float64","int64" ],
                               ["Genre","0.01%","удаление 2 строк с пропусками в практически во всех признаках","object","-"],
                               ["NA_sales","-","-","float64","-,"],
                               ["EU_sales","-","-","float64","-"],
                               ["JP_sales","-","-","float64","-"],
                               ["Other_sales","-","-","float64","-"],
                               ["Critic_Score","51.32%","заменить 'nan' на '0'","float64","-"],
                               ["User_Score","40.09%","заменить 'nan' на '-1', 'tbd' на ''-2'","object","float64"],
                               ["Rating","40.48%","заменить 'K-A' на 'E', 'nan' и 'RP' на ' '","object","-"]],
                              columns=["Признак","Пропущенные значения (%)","Замена пропущенных значений","Тип данных","Замена типа данных"])

# %%
(conclusion


 .style

 .set_caption('Таблица 2. Найденные проблемы в признаках')
 
)
# Out:
# <style  type="text/css" >
# </style><table id="T_7dcdbf78_d842_11ec_b3ba_98460a9f726e" ><caption>Таблица 2. Найденные проблемы в признаках</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Признак</th>        <th class="col_heading level0 col1" >Пропущенные значения (%)</th>        <th class="col_heading level0 col2" >Замена пропущенных значений</th>        <th class="col_heading level0 col3" >Тип данных</th>        <th class="col_heading level0 col4" >Замена типа данных</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7dcdbf78_d842_11ec_b3ba_98460a9f726elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7dcdbf78_d842_11ec_b3ba_98460a9f726erow0_col0" class="data row0 col0" >Name</td>
#                         <td id="T_7dcdbf78_d842_11ec_b3ba_98460a9f726erow0_col1" class="data row0 col1" >0.01%</td>
# ...

# %% [markdown]
# Также в ходе изучения информации о датасете,необходимо было найти, что означают аббревиатуры рейтинга игр ESRB. В таблице 3 представлено полное описание.

# %%
ESRB=pd.DataFrame([["EC", "Early childhood", "Для детей младшего возраста (от 3 лет и старше)", "Не содержит материалов, которые родители могли бы счесть неподходящими. Изначально разрабатываются для детей и обычно представляют собой развивающие игры."],
                   ["E (K-A)", "Everyone (Kids to Adults)", "Для всех (от 6 лет и старше)", "Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера."],
                   ["E10+", "Everyone 10 and older ", "Для всех от 10 лет и старше", "Игры могут содержать немного больше мультипликационного или мягкого насилия, или несколько откровенные сцены или минимальное количество крови."],
                   ["T", "Teen", "Подросткам (от 13 лет и старше)", "Игры могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики."],
                   ["M", "Mature", "Для взрослых (от 17 лет и старше)","Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории"],
                   ["AO", "Adults Only 18+", "Только для взрослых (от 18 лет и старше)","Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое, а также сцены с обнажением."],
                   ["RP", "Rating Pending", "Рейтинг ожидается", "Продукт был отправлен в ESRB и ожидает присвоения рейтинга."]],
                   columns=["Аббревиатура","Англ.","Рус.","Описание"]
    
)

# %%
(ESRB


 .style

 .set_caption('Таблица 3. РЕЙТИНГ ИГР ESRB (Entertainment Software Rating Board)')
 
)
# Out:
# <style  type="text/css" >
# </style><table id="T_7dd3b0f4_d842_11ec_b3ba_98460a9f726e" ><caption>Таблица 3. РЕЙТИНГ ИГР ESRB (Entertainment Software Rating Board)</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Аббревиатура</th>        <th class="col_heading level0 col1" >Англ.</th>        <th class="col_heading level0 col2" >Рус.</th>        <th class="col_heading level0 col3" >Описание</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7dd3b0f4_d842_11ec_b3ba_98460a9f726elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7dd3b0f4_d842_11ec_b3ba_98460a9f726erow0_col0" class="data row0 col0" >EC</td>
#                         <td id="T_7dd3b0f4_d842_11ec_b3ba_98460a9f726erow0_col1" class="data row0 col1" >Early childhood</td>
# ...

# %% [markdown]
# ## Шаг 2. Предобработка данных для признаков <a name="step2"></a>

# %% [markdown]
# ##### Изменение названий признаков <a name="change_feature_name"></a>

# %% [markdown]
# Для начала преобразую шапку датасета - изменю названия для признаков, а именно переведу их в нижний регистр.

# %%
data.columns=data.columns.str.lower()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### Замена пропущенных значений <a name="change_nan"></a>

# %% [markdown]
# ##### Удаление полпустых строк <a name="drop_half-empty_lines"></a>

# %%
data=data.drop([14244])
data=data.drop([659])

# %%
data['name'].isnull().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %%
data.reset_index(drop=True, inplace=True)

# %%
#проверка на сброс индекса
display(data.loc[[14244]])
display(data.loc[[659]])
# Out:
#                                        name platform  year_of_release  \
# 14244  Mashiro Iro Symphony: *mutsu-no-hana      PSP           2011.0
#
#            genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 14244  Adventure       0.0       0.0      0.03          0.0           NaN
#
#       user_score rating
# 14244        NaN    NaN
#             name platform  year_of_release genre  na_sales  eu_sales  \
# 659  Guitar Hero      PS2           2005.0  Misc      1.67      0.61
#
#      jp_sales  other_sales  critic_score user_score rating
# 659      0.03         0.07          91.0        8.7      T

# %% [markdown]
# ##### Замена пропущенных значений для признака critic_score <a name="change_nan_critic_score"></a>

# %%
data['critic_score']=data['critic_score'].fillna(0)

# %%
data['critic_score'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### Замена типа данных для признака critic_score <a name="change_data_type_critic_score"></a>

# %%
data['critic_score']=data['critic_score'].astype('float')

# %%
data['critic_score'].describe().T
# Out:
# count    16713.000000
# mean        33.578053
# std         35.818495
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         70.000000
# max         98.000000
# Name: critic_score, dtype: float64

# %% [markdown]
# ##### Замена пропущенных значений для признака user_score <a name="change_nan_user_score"></a>

# %% [markdown]
# Заменять буду на значения **-1** и **-2**, потому что 0 уже есть и он характеризует оценку от 0 до 10.

# %%
data['user_score']=data['user_score'].fillna(-1)

# %%
data['user_score']=data['user_score'].replace('tbd',-2)

# %%
data['user_score'].unique()
# Out:
# array(['8', -1, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', -2, '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
data['user_score'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### Замена типа данных для признака user_score <a name="change_data_type_user_score"></a>

# %%
data['user_score']=data['user_score'].astype('float')

# %%
data['user_score'].describe().T
# Out:
# count    16713.000000
# mean         2.544851
# std          4.310728
# min         -2.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%          7.300000
# max          9.700000
# Name: user_score, dtype: float64

# %% [markdown]
# ##### Замена пропущенных значений для признака rating<a name="change_nan_rating"></a>

# %%
data['rating']=data['rating'].fillna('no rating')

# %%
data['rating']=data['rating'].replace('K-A','E')

# %%
data['rating'].unique()
# Out:
# array(['E', 'no rating', 'M', 'T', 'E10+', 'AO', 'EC', 'RP'], dtype=object)

# %%
data['rating'].isnull().sum()
# Out:
# 0

# %%
data['rating'].describe().T
# Out:
# count         16713
# unique            8
# top       no rating
# freq           6764
# Name: rating, dtype: object

# %% [markdown]
# ##### Замена пропущенных значений для признака year_of_release<a name="change_nan_year_of_release"></a>

# %%
# создам сводгую таблциу по сгруппированным данным названия игры и по средним годам релиза
group_name=data.groupby('name')['year_of_release'].mean()

# %%
#заполню пропуски на средний год, основываясь на названии игры
for i in group_name.index:
    data.loc[(data['name']==i)&(data['year_of_release'].isnull()),'year_of_release']=group_name[i]

# %%
data['year_of_release'].isnull().sum()
# Out:
# 146

# %%
missing_percent(data['year_of_release'])
# Out:
# Процент пропущенных значений: 0.87% , количество пропущенных значений в выборке: 146.

# %% [markdown]
# Заменить получилось не все значения, остальные года заменю на 0.

# %%
display(group_name)
# Out:
# name
#  Beyblade Burst                 2016.0
#  Fire Emblem Fates              2015.0
#  Frozen: Olaf's Quest           2013.0
#  Haikyu!! Cross Team Match!     2016.0
#  Tales of Xillia 2              2012.0
#                                  ...
# thinkSMART: Chess for Kids      2011.0
# uDraw Studio                    2010.0
# uDraw Studio: Instant Artist    2011.0
# wwe Smackdown vs. Raw 2006         NaN
# ¡Shin Chan Flipa en colores!    2007.0
# Name: year_of_release, Length: 11559, dtype: float64

# %%
data['year_of_release']=data['year_of_release'].fillna(0)

# %%
data['year_of_release'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##### Замена типа данных для признака year_of_release <a name="change_data_type_year_of_release"></a>

# %%
data['year_of_release']=data['year_of_release'].astype('int')

# %%
data['year_of_release'].describe().T
# Out:
# count    16713.000000
# mean      1988.961886
# std        186.812551
# min          0.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: year_of_release, dtype: float64

# %% [markdown]
# ##### Расчет нового признака и добавление в таблицу<a name="add_feature"></a>

# %%
data['total_sales']=data['na_sales']+data['eu_sales']+data['jp_sales']+data['other_sales']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     16713 non-null  float64
#  9   user_score       16713 non-null  float64
#  10  rating           16713 non-null  object
#  11  total_sales      16713 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 0     28.96      3.77         8.45          76.0         8.0          E
# 1      3.58      6.81         0.77           0.0        -1.0  no rating
# 2     12.76      3.79         3.29          82.0         8.3          E
# 3     10.93      3.28         2.95          80.0         8.0          E
# 4      8.89     10.22         1.00           0.0        -1.0  no rating
#
#    total_sales
# 0        82.54
# 1        40.24
# ...

# %%
data.query('total_sales==0')
# Out:
#                                                    name platform  \
# 16674                                  G1 Jockey 4 2008      PS3
# 16707  SCORE International Baja 1000: The Official Game      PS2
#
#        year_of_release   genre  na_sales  eu_sales  jp_sales  other_sales  \
# 16674             2008  Sports       0.0       0.0       0.0          0.0
# 16707             2008  Racing       0.0       0.0       0.0          0.0
#
#        critic_score  user_score     rating  total_sales
# 16674           0.0        -1.0  no rating          0.0
# 16707           0.0        -1.0  no rating          0.0

# %%
data.query('name=="G1 Jockey 4 2008"')
# Out:
#                    name platform  year_of_release   genre  na_sales  eu_sales  \
# 16674  G1 Jockey 4 2008      PS3             2008  Sports       0.0       0.0
#
#        jp_sales  other_sales  critic_score  user_score     rating  total_sales
# 16674       0.0          0.0           0.0        -1.0  no rating          0.0

# %%
data.query('name=="SCORE International Baja 1000: The Official Game"')
# Out:
#                                                    name platform  \
# 9664   SCORE International Baja 1000: The Official Game     X360
# 10678  SCORE International Baja 1000: The Official Game      Wii
# 11718  SCORE International Baja 1000: The Official Game      PS3
# 16707  SCORE International Baja 1000: The Official Game      PS2
#
#        year_of_release   genre  na_sales  eu_sales  jp_sales  other_sales  \
# 9664              2008  Racing      0.11      0.01       0.0         0.01
# 10678             2008  Racing      0.09      0.00       0.0         0.01
# 11718             2008  Racing      0.07      0.00       0.0         0.01
# 16707             2008  Racing      0.00      0.00       0.0         0.00
#
#        critic_score  user_score     rating  total_sales
# 9664            0.0        -1.0  no rating         0.13
# 10678           0.0        -1.0  no rating         0.10
# 11718           0.0        -1.0  no rating         0.08
# ...

# %% [markdown]
# Были обнаружены еще полупустые строки, но их удалять не буду, так как будет исследование по годам и играм,а данные по этим признакам заполнены.

# %% [markdown]
# ## Вывод по шагу 2. <a name="step2_conclusion"></a>

# %%
conclusion_2 = pd.DataFrame([["name","0.01%","0%","были удалены 2 строки, так как пропусками были практически во всех признаках","-","-"],
                               ["year_of_release","1.61%","0.87%","были заменены пропуски средними значениями для разных выборок игр, но так как это сократило пропуски почти в два раза, остальные данные были заменены на '0'","int64","год должен иметь целочисленный тип данных" ],
                               ["genre","0.01%","0%","были удалены 2 строки, которые были обнаружены и в признаке 'name'","-","-"],
                               ["critic_score","51.32%","0%","так как оценка состоит из максимум ста баллов, а значений '0' не было обнаружено, значения 'nan' были знзаменены на '0'","-","-"],
                               ["user_score","40.09%","0%","так как оценка состоит из максимум 10 баллов и были обнаружены оценки 0 (предполагаю, что это реальная оценка), были заменены значения 'nan' на '-1', 'tbd' на ''-2'","float64","до этого в признаке был обнаружен тип данных 'object', что помешает в дальнейшем исследовании признаков"],
                               ["rating","40.48%","0%","так как рейтинг 'K-A' старая версия рейтинга 'E', были заменены 'K-A' на 'E', а значения 'RP' приравниваются к'nan', потому что RP подразумевает ожидание рейтинга,то есть рейтинга нет, были заменены 'nan' и 'RP' на пустую строку,так как признак имеет тип данных 'object'","-","-"]],
                              columns=["Признак (переведены в нижний регистр)","Пропущенные значения (%)","Пропущенные значения после замены(%)","Обоснование замены пропущенных значений","Измененный тип данных","Обоснование замены типа данных"])

# %%
(conclusion_2


 .style

 .set_caption('Таблица 4. Исправленные проблемы в признаках')
 
)
# Out:
# <style  type="text/css" >
# </style><table id="T_947e7334_d842_11ec_b3ba_98460a9f726e" ><caption>Таблица 4. Исправленные проблемы в признаках</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Признак (переведены в нижний регистр)</th>        <th class="col_heading level0 col1" >Пропущенные значения (%)</th>        <th class="col_heading level0 col2" >Пропущенные значения после замены(%)</th>        <th class="col_heading level0 col3" >Обоснование замены пропущенных значений</th>        <th class="col_heading level0 col4" >Измененный тип данных</th>        <th class="col_heading level0 col5" >Обоснование замены типа данных</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_947e7334_d842_11ec_b3ba_98460a9f726elevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_947e7334_d842_11ec_b3ba_98460a9f726erow0_col0" class="data row0 col0" >name</td>
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных <a name="step3"></a>

# %% [markdown]
# ##### Нахождение количества игр по разным годам <a name="3.1"></a>

# %% [markdown]
# * Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
#сформирую сводную таблицу
number_of_games_by_year=data.pivot_table(index='year_of_release', values='name',aggfunc='count')

# %%
number_of_games_by_year.columns = number_of_games_by_year.columns.str.replace('name','count')

# %%
#возьму выборку без пропущенных годов
number_of_games_by_year=number_of_games_by_year.query('year_of_release>0')

# %%
number_of_games_by_year.describe().T
# Out:
#        count        mean         std  min   25%    50%    75%     max
# count   37.0  447.756757  455.802918  9.0  36.0  339.0  764.0  1441.0

# %%
number_of_games_by_year.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('count')
sns.barplot(y='count',x='year_of_release',data=number_of_games_by_year).set_title("Number of games released over the years")
plt.xticks(number_of_games_by_year.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# С 1994 года заметен рост количества выпущенных игр, проверю во сколько раз выпущенных игр больше в 1994 году, чем в 1993 году.

# %%
(number_of_games_by_year.query('year_of_release<1996'))
# Out:
#     year_of_release  count
# 0              1980      9
# 1              1981     46
# 2              1982     36
# 3              1983     17
# 4              1984     14
# 5              1985     14
# 6              1986     21
# 7              1987     16
# 8              1988     15
# 9              1989     17
# 10             1990     16
# 11             1991     41
# 12             1992     43
# 13             1993     60
# 14             1994    121
# 15             1995    219

# %% [markdown]
# Вижу, что количество возрасло за год в два раза, следовательно незначительную часть (раньше 1994 года ) можно не брать в учет.

# %%
number_of_games_by_year.describe().T
# Out:
#                  count         mean         std     min     25%     50%  \
# year_of_release   37.0  1998.000000   10.824355  1980.0  1989.0  1998.0
# count             37.0   447.756757  455.802918     9.0    36.0   339.0
#
#                     75%     max
# year_of_release  2007.0  2016.0
# count             764.0  1441.0

# %%
def upper (q1,q3):
    interquartile_range=q3-q1
    upper_mustache=q3+1.5*interquartile_range
    return upper_mustache

# %%
upper(36,764)
# Out:
# 1856.0

# %% [markdown]
# Нижний квантиль равен 36, верхний 1856.

# %%
number_of_games_by_year=number_of_games_by_year.query('year_of_release >=1994')

# %%
display(number_of_games_by_year.head())
# Out:
#     year_of_release  count
# 14             1994    121
# 15             1995    219
# 16             1996    263
# 17             1997    289
# 18             1998    380

# %% [markdown]
# ##### Построение распределения продаж по платформам <a name="3.2"></a>

# %% [markdown]
# * Посмотрите, как менялись продажи по платформам.
# * Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.
# * За какой характерный срок появляются новые и исчезают старые платформы?

# %%
sales_by_platform=data.pivot_table(index='platform',values='total_sales',aggfunc='sum')

# %%
sales_by_platform=sales_by_platform.sort_values(by=['total_sales'],ascending=False)

# %%
sales_by_platform.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('platform')
plt.ylabel('total_sales')
sns.barplot(y='total_sales',x='platform',data=sales_by_platform).set_title("Sales by platforms")
plt.xticks(sales_by_platform.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# Всего в выборке 31 платформа, возьмем для рассмотрения 7 топовых платформ.

# %%
text='ТОП 7 '
x=text.center(20)
print(' ')
print(x)
display(sales_by_platform.head(7))
# Out:
#
#        ТОП 7
#   platform  total_sales
# 0      PS2      1255.77
# 1     X360       971.42
# 2      PS3       939.65
# 3      Wii       907.51
# 4       DS       806.12
# 5       PS       730.86
# 6      GBA       317.85

# %% [markdown]
# ##### Платформа 'PS2' <a name="PS2"></a>

# %%
sales_by_platform_and_years=data.pivot_table(index=['year_of_release','platform'],values='total_sales')

# %%
sales_PS2_by_years=sales_by_platform_and_years.query('platform == "PS2" and year_of_release > 0')

# %%
display(sales_PS2_by_years)
# Out:
#                           total_sales
# year_of_release platform
# 2000            PS2          0.477683
# 2001            PS2          0.899622
# 2002            PS2          0.731088
# 2003            PS2          0.749035
# 2004            PS2          0.817799
# 2005            PS2          0.616513
# 2006            PS2          0.396908
# 2007            PS2          0.353953
# 2008            PS2          0.282199
# 2009            PS2          0.275000
# 2010            PS2          0.148421
# 2011            PS2          0.064286

# %%
sales_PS2_by_years.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('total_sales')
sns.barplot(data=sales_PS2_by_years, y='total_sales', x='year_of_release', palette="Reds").set_title("Sales by PS2 platform")
plt.xticks(sales_PS2_by_years.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# Время существования платформы **PS2** - 12 лет

# %% [markdown]
# ##### Платформа 'X360' <a name="X360"></a>

# %%
sales_X360_by_years=sales_by_platform_and_years.query('platform == "X360" and year_of_release > 0')

# %%
display(sales_X360_by_years)
# Out:
#                           total_sales
# year_of_release platform
# 2005            X360         0.439048
# 2006            X360         0.550957
# 2007            X360         0.775691
# 2008            X360         0.925646
# 2009            X360         0.694368
# 2010            X360         0.921892
# 2011            X360         0.685047
# 2012            X360         0.932593
# 2013            X360         1.181067
# 2014            X360         0.551429
# 2015            X360         0.341714
# 2016            X360         0.116923

# %%
sales_X360_by_years.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('total_sales')
sns.barplot(y='total_sales',x='year_of_release',data=sales_X360_by_years,palette="Greens").set_title("Sales by X360 platform")
plt.xticks(sales_X360_by_years.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# Время существования платформы **X360** - 12 лет

# %% [markdown]
# ##### Платформа 'PS3' <a name="PS3"></a>

# %%
sales_PS3_by_years=sales_by_platform_and_years.query('platform == "PS3" and year_of_release > 0')

# %%
display(sales_PS3_by_years)
# Out:
#                           total_sales
# year_of_release platform
# 2001            PS3          0.480000
# 2005            PS3          0.190000
# 2006            PS3          0.776296
# 2007            PS3          0.813222
# 2008            PS3          0.854604
# 2009            PS3          0.808210
# 2010            PS3          0.764492
# 2011            PS3          0.721370
# 2012            PS3          0.726711
# 2013            PS3          0.898810
# 2014            PS3          0.442222
# 2015            PS3          0.230411
# 2016            PS3          0.094737

# %%
sales_PS3_by_years.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('total_sales')
sns.barplot(y='total_sales',x='year_of_release',data=sales_PS3_by_years,palette="Blues").set_title("Sales by PS3 platform")
plt.xticks(sales_PS3_by_years.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# Время существования платформы **PS3** - 13 лет

# %% [markdown]
# ##### Платформа 'Wii' <a name="Wii"></a>

# %%
sales_Wii_by_years=sales_by_platform_and_years.query('platform == "Wii" and year_of_release != 0')

# %%
display(sales_Wii_by_years)
# Out:
#                           total_sales
# year_of_release platform
# 2006            Wii          2.920625
# 2007            Wii          0.820374
# 2008            Wii          0.621259
# 2009            Wii          0.636831
# 2010            Wii          0.506575
# 2011            Wii          0.409521
# 2012            Wii          0.716875
# 2013            Wii          0.715833
# 2014            Wii          0.625000
# 2015            Wii          0.285000
# 2016            Wii          0.180000

# %%
sales_Wii_by_years.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('total_sales')
sns.barplot(data=sales_Wii_by_years, x='year_of_release', y='total_sales', palette="Reds").set_title("Sales by Wii platform")
plt.xticks(sales_Wii_by_years.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# Время существования платформы **Wii** - 11 лет.

# %% [markdown]
# ##### Платформа DS <a name="DS"></a>

# %%
sales_DS_by_years=sales_by_platform_and_years.query('platform == "DS" and year_of_release != 0')

# %%
display(sales_DS_by_years)
# Out:
#                           total_sales
# year_of_release platform
# 1985            DS           0.020000
# 2004            DS           0.750870
# 2005            DS           1.102881
# 2006            DS           0.596070
# 2007            DS           0.390531
# 2008            DS           0.294251
# 2009            DS           0.295941
# 2010            DS           0.263426
# 2011            DS           0.169871
# 2012            DS           0.486250
# 2013            DS           0.192500

# %%
sales_DS_by_years.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('total_sales')
sns.barplot(data=sales_DS_by_years, x='year_of_release', y='total_sales', palette="Greens").set_title("Sales by DS platform")
plt.xticks(sales_DS_by_years.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# Время существования платформы **DS** - 11 лет

# %% [markdown]
# ##### Платформа PS <a name="PS"></a>

# %%
sales_PS_by_years=sales_by_platform_and_years.query('platform == "PS" and year_of_release != 0')

# %%
display(sales_PS_by_years)
# Out:
#                           total_sales
# year_of_release platform
# 1994            PS           0.354706
# 1995            PS           0.363232
# 1996            PS           0.577439
# 1997            PS           0.724309
# 1998            PS           0.683427
# 1999            PS           0.722650
# 2000            PS           0.602312
# 2001            PS           0.391099
# 2002            PS           0.333500
# 2003            PS           0.690000

# %%
sales_PS_by_years.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('total_sales')
sns.barplot(data=sales_PS_by_years, x='year_of_release', y='total_sales', palette="Blues").set_title("Sales by PS platform")
plt.xticks(sales_PS_by_years.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# Время существования платформы **PS** - 10 лет

# %% [markdown]
# ##### Платформа GBA	 <a name="GBA"></a>

# %%
sales_GBA_by_years=sales_by_platform_and_years.query('platform == "GBA" and year_of_release != 0')

# %%
display(sales_GBA_by_years)
# Out:
#                           total_sales
# year_of_release platform
# 2000            GBA          0.070000
# 2001            GBA          0.575047
# 2002            GBA          0.374545
# 2003            GBA          0.377800
# 2004            GBA          0.445200
# 2005            GBA          0.253897
# 2006            GBA          0.136500
# 2007            GBA          0.566667

# %%
sales_GBA_by_years.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
# plt.xlabel('year_of_release')
# plt.ylabel('total_sales')
sns.barplot(data=sales_GBA_by_years, x='year_of_release', y='total_sales', palette="Reds").set_title("Sales by GBA platform")
plt.xticks(sales_GBA_by_years.index, rotation=75, fontsize=15)
plt.grid=True

# %% [markdown]
# Время существования платформы **GBA** - 8 лет

# %%
platforms = pd.DataFrame([["PS",12],
                          ["X360",12],
                          ["PS3", 13],
                          ["Wii", 11],
                          ["DS", 11],
                          ["PS", 10],
                          ["GBA", 8]],
                               
                               columns=["Название платформы","Время существования"])

# %%
display(platforms)
# Out:
#   Название платформы  Время существования
# 0                 PS                   12
# 1               X360                   12
# 2                PS3                   13
# 3                Wii                   11
# 4                 DS                   11
# 5                 PS                   10
# 6                GBA                    8

# %%
platforms.describe().T
# Out:
#                      count  mean       std  min   25%   50%   75%   max
# Время существования    7.0  11.0  1.632993  8.0  10.5  11.0  12.0  13.0

# %% [markdown]
# ##### Вывод:
# Время существования платформы примерно 11 лет

# %% [markdown]
# ##### Построение распределения продаж по платформам за актуальный период  <a name="3.3"></a>

# %% [markdown]
# * Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# * Не учитывайте в работе данные за предыдущие годы.
# * Какие платформы лидируют по продажам, растут или падают?
# * Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# В ходе исследований предыдущего шага мною было определено, что в среднем время существования платформы соответствует 10 годам.
# Прогноз необходимо построить на 2017 год, следовательно актуальным периодом будет промежуток от 2006 года до 2016.

# %%
platforms=list(data.query('year_of_release > = 2010 and year_of_release <=2016')['platform'].unique())

# %%
display(platforms)
# Out:
# ['X360',
#  'PS3',
#  'DS',
#  'PS4',
#  '3DS',
#  'Wii',
#  'XOne',
#  'WiiU',
#  'PC',
#  'PSP',
#  'PSV',
#  'PS2']

# %%
actual_period=(
                  data.query('year_of_release > = 2010 and year_of_release <=2016')
                  .sort_values(by=['platform','year_of_release'],ascending=True)
                  .pivot_table(index=['platform','year_of_release'],values=['total_sales'], aggfunc='sum')

                  )

# %%
actual_period.reset_index(inplace=True)

# %%
g = sns.FacetGrid(actual_period,col="platform",col_wrap=2,hue="platform",aspect=2,xlim=(2010,2016))
g.map_dataframe(sns.lineplot, x="year_of_release", y="total_sales")
g.set_axis_labels("year_of_release", "total_sales")
# order=actual_period['year_of_release'].unique()

# %% [markdown]
# ##### Вывод
# По графикам видно, что наиболее прибыльными платформами для 2017 года будут следующие: XOne, PS4. У остальных платформ к 2017 году продажи падают.

# %% [markdown]
# ##### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.<a name="3.4"></a>

# %%
by_global_sales=data.pivot_table(index='name',columns='platform',values='total_sales')

# %%
by_global_sales.reset_index(inplace=True)

# %%
d=by_global_sales.describe().T

# %%
onequartile_percent_sorted=d.sort_values(by='25%')

# %%
display(onequartile_percent_sorted)
# Out:
#            count      mean       std   min     25%    50%     75%    max
# platform
# 3DO          3.0  0.033333  0.023094  0.02  0.0200  0.020  0.0400   0.06
# PSV        430.0  0.125744  0.212193  0.01  0.0200  0.055  0.1300   1.96
# PC         973.0  0.266531  0.675903  0.01  0.0200  0.050  0.1700   8.01
# PSP       1209.0  0.243218  0.520210  0.01  0.0300  0.090  0.2300   7.68
# PCFX         1.0  0.030000       NaN  0.03  0.0300  0.030  0.0300   0.03
# GG           1.0  0.040000       NaN  0.04  0.0400  0.040  0.0400   0.04
# TG16         2.0  0.080000  0.084853  0.02  0.0500  0.080  0.1100   0.14
# 3DS        520.0  0.498077  1.430876  0.01  0.0500  0.120  0.3300  14.60
# DS        2151.0  0.374765  1.426451  0.01  0.0500  0.110  0.2700  29.80
# GBA        822.0  0.386679  0.896897  0.01  0.0525  0.160  0.3900  15.84
# SCD          6.0  0.310000  0.584055  0.04  0.0525  0.065  0.1225   1.50
# NG          12.0  0.120000  0.082241  0.02  0.0550  0.100  0.2000   0.25
# ...

# %%
DO=sales_by_platform_and_years.query('platform == "3DO"')
PSV=sales_by_platform_and_years.query('platform=="PSV" and year_of_release!=0')
PC=sales_by_platform_and_years.query('platform=="PC" and year_of_release!=0')
NES=sales_by_platform_and_years.query('platform=="NES" and year_of_release!=0')

# %%
display(DO)
# Out:
#                           total_sales
# year_of_release platform
# 1994            3DO              0.02
# 1995            3DO              0.04

# %% [markdown]
# Платформа **3DO** просуществовала 2 года с небольшими продажами и разорилась.

# %%
display(PSV)
# Out:
#                           total_sales
# year_of_release platform
# 2011            PSV          0.257222
# 2012            PSV          0.305472
# 2013            PSV          0.168095
# 2014            PSV          0.119000
# 2015            PSV          0.056818
# 2016            PSV          0.050000

# %% [markdown]
# Портативная консоль была следующей после PSP-E1000, поэтому не удивительно что первый квартиль продаж минимальный.

# %%
display(PC)
# Out:
#                           total_sales
# year_of_release platform
# 1985            PC           0.040000
# 1988            PC           0.030000
# 1992            PC           0.606000
# 1994            PC           2.145000
# 1995            PC           2.110000
# 1996            PC           2.645000
# 1997            PC           1.878333
# 1998            PC           0.407500
# 1999            PC           0.677143
# 2000            PC           0.665714
# 2001            PC           0.364667
# 2002            PC           0.451053
# 2003            PC           0.261471
# 2004            PC           0.346333
# 2005            PC           0.115263
# 2006            PC           0.054808
# 2007            PC           0.149677
# 2008            PC           0.161818
# 2009            PC           0.157870
# 2010            PC           0.284239
# 2011            PC           0.249362
# 2012            PC           0.372222
# 2013            PC           0.317317
# ...

# %% [markdown]
# IBM PC — первый массовый персональный компьютер производства фирмы IBM, выпущенный в 1981 году, так как у большинства людей и компьютера то не было, то вполне логичны минимальные продажи игр на персональные компьютеры в 1984 году.

# %%
display(NES)
# Out:
#                           total_sales
# year_of_release platform
# 1983            NES          1.826667
# 1984            NES          3.852308
# 1985            NES          4.858182
# 1986            NES          1.916316
# 1987            NES          1.976000
# 1988            NES          4.091818
# 1989            NES          1.570000
# 1990            NES          1.966250
# 1991            NES          0.872857
# 1992            NES          0.660000
# 1993            NES          0.902500
# 1994            NES          0.110000

# %% [markdown]
# Платформа NES имела высокую популярность, пока не стали выпускаться игры на персональные компьютеры, от этого и первый квартиль такой высокий по отношению к другим платформам. Поддержка данной консоли прекратилась в 2003 году по историческим данным.

# %% [markdown]
# ##### Промежуточный вывод:
# Минимальные продажи 1-го квартиля у 3DO, PSV, PC.
# Максимальные продажи 1-го квартиля у NES.

# %%
max_percent_sorted=d.sort_values(by='max',ascending=False)

# %%
display(max_percent_sorted)
# Out:
#            count      mean       std   min     25%    50%     75%    max
# platform
# Wii       1320.0  0.687508  3.126609  0.01  0.0800  0.190  0.4825  82.54
# NES         98.0  2.561735  5.108012  0.06  1.0000  1.375  2.2225  40.24
# GB          98.0  2.606735  5.365478  0.06  0.3025  1.165  2.1650  31.38
# DS        2151.0  0.374765  1.426451  0.01  0.0500  0.110  0.2700  29.80
# X360      1261.0  0.769243  1.616204  0.01  0.1100  0.280  0.7500  21.82
# PS3       1329.0  0.705448  1.391759  0.00  0.1100  0.270  0.7500  21.05
# PS2       2161.0  0.581106  1.137927  0.00  0.0800  0.230  0.5600  20.81
# SNES       239.0  0.836987  1.869469  0.01  0.1350  0.320  0.7050  20.62
# GBA        822.0  0.386679  0.896897  0.01  0.0525  0.160  0.3900  15.84
# PS4        392.0  0.801378  1.609456  0.01  0.0600  0.200  0.7300  14.63
# 3DS        520.0  0.498077  1.430876  0.01  0.0500  0.120  0.3300  14.60
# N64        319.0  0.685517  1.316733  0.01  0.1350  0.270  0.5950  11.90
# ...

# %%
PCFX=sales_by_platform_and_years.query('platform == "PCFX"')

# %%
display(PCFX)
# Out:
#                           total_sales
# year_of_release platform
# 1996            PCFX             0.03

# %% [markdown]
# Время жизни для данной платформы составаило 1 год c очень маленькими продажами.

# %%
Wii=sales_by_platform_and_years.query('platform == "Wii" and year_of_release!=0 ')

# %%
display(Wii)
# Out:
#                           total_sales
# year_of_release platform
# 2006            Wii          2.920625
# 2007            Wii          0.820374
# 2008            Wii          0.621259
# 2009            Wii          0.636831
# 2010            Wii          0.506575
# 2011            Wii          0.409521
# 2012            Wii          0.716875
# 2013            Wii          0.715833
# 2014            Wii          0.625000
# 2015            Wii          0.285000
# 2016            Wii          0.180000

# %% [markdown]
# Nintendo Wii является наследником Nintendo GameCube(GC).

# %% [markdown]
# ##### Промежуточный вывод:
# Максимальные выбросы в продажах  у Wii, минимальный выброс у PCFX.

# %% [markdown]
# ##### Ящик с усами для всех платформ и всех лет

# %%
fig, ax = plt.subplots(figsize=(8, 20))
plt.xlim(0,5)
plt.xlabel('total_sales (millions)')
sns.boxplot(data=by_global_sales, orient='h').set_title("Sales by gloabal sales on platform")
ax.grid=True

# %% [markdown]
# ##### Вывод:
# Провальные игры были выпущены для платформы PCFX.
# Популярные игры были выпущены для платформы Wii.

# %%
by_global_sales_actual=data.query('year_of_release >=2006 and year_of_release <= 2016').pivot_table(index='name',columns='platform',values='total_sales')

# %%
by_global_sales_actual.reset_index(inplace=True)

# %%
a=by_global_sales_actual.describe().T

# %%
onequartile_percent_sorted=a.sort_values(by='25%')

# %%
display(onequartile_percent_sorted)
# Out:
#            count      mean       std   min     25%    50%     75%    max
# platform
# PC         787.0  0.211512  0.542390  0.01  0.0200  0.050  0.1700   8.01
# PSV        429.0  0.125431  0.212341  0.01  0.0200  0.050  0.1300   1.96
# GBA         46.0  0.192609  0.342413  0.01  0.0225  0.070  0.2425   1.76
# DC           2.0  0.030000  0.014142  0.02  0.0250  0.030  0.0350   0.04
# PS2        809.0  0.329394  0.616452  0.00  0.0300  0.130  0.3800   5.95
# PSP       1093.0  0.222022  0.466304  0.01  0.0300  0.080  0.2200   5.49
# XB          66.0  0.163182  0.192986  0.01  0.0300  0.080  0.2000   1.03
# DS        1987.0  0.330574  1.086094  0.01  0.0400  0.110  0.2700  29.80
# 3DS        514.0  0.502938  1.438494  0.01  0.0500  0.125  0.3375  14.60
# PS4        392.0  0.801378  1.609456  0.01  0.0600  0.200  0.7300  14.63
# XOne       247.0  0.645020  1.036139  0.01  0.0600  0.220  0.6850   7.39
# WiiU       147.0  0.559116  1.058836  0.01  0.0800  0.220  0.5250   7.09
# ...

# %% [markdown]
# ##### Промежуточный вывод:
# Минимальное значение первого квартиля у PC и PSV для актуального периода.
# Максимальное значение первого квартиля у X360 для актального периода.

# %%
max_percent_sorted=a.sort_values(by='max',ascending=False)

# %%
display(max_percent_sorted)
# Out:
#            count      mean       std   min     25%    50%     75%    max
# platform
# Wii       1301.0  0.694320  3.148382  0.01  0.0900  0.190  0.5000  82.54
# DS        1987.0  0.330574  1.086094  0.01  0.0400  0.110  0.2700  29.80
# X360      1229.0  0.778999  1.633930  0.01  0.1100  0.280  0.7700  21.82
# PS3       1317.0  0.708607  1.397119  0.00  0.1100  0.270  0.7600  21.05
# PS4        392.0  0.801378  1.609456  0.01  0.0600  0.200  0.7300  14.63
# 3DS        514.0  0.502938  1.438494  0.01  0.0500  0.125  0.3375  14.60
# PC         787.0  0.211512  0.542390  0.01  0.0200  0.050  0.1700   8.01
# XOne       247.0  0.645020  1.036139  0.01  0.0600  0.220  0.6850   7.39
# WiiU       147.0  0.559116  1.058836  0.01  0.0800  0.220  0.5250   7.09
# PS2        809.0  0.329394  0.616452  0.00  0.0300  0.130  0.3800   5.95
# PSP       1093.0  0.222022  0.466304  0.01  0.0300  0.080  0.2200   5.49
# PSV        429.0  0.125431  0.212341  0.01  0.0200  0.050  0.1300   1.96
# ...

# %% [markdown]
# ##### Промежуточный вывод:
# Минимальное значение максимума у DC  для актуального периода.
# Максимальное значение максимума у Wii для актального периода.

# %% [markdown]
# ##### Ящик с усами для актуального периода

# %%
fig, ax = plt.subplots(figsize=(8, 20))
plt.xlim(-0.1,3)
plt.xlabel('total_sales')
sns.boxplot(data=by_global_sales_actual, orient='h').set_title("Sales by gloabal sales on platform")
ax.grid=True

# %%
DC_actual=sales_by_platform_and_years.query('platform=="DC" and year_of_release>=2006 and year_of_release<=2016')

# %%
display(DC_actual)
# Out:
#                           total_sales
# year_of_release platform
# 2007            DC               0.02
# 2008            DC               0.04

# %%
XB_actual=sales_by_platform_and_years.query('platform=="XB"and year_of_release>=2006 and year_of_release<=2016')

# %%
display(XB_actual)
# Out:
#                           total_sales
# year_of_release platform
# 2006            XB           0.161935
# 2007            XB           0.183333
# 2008            XB           0.180000

# %% [markdown]
# Время жизни платформы закончилось в 2008 году.

# %%
Wii_actual=sales_by_platform_and_years.query('platform=="Wii" and year_of_release>=2006 and year_of_release<=2016')

# %%
display(Wii_actual)
# Out:
#                           total_sales
# year_of_release platform
# 2006            Wii          2.920625
# 2007            Wii          0.820374
# 2008            Wii          0.621259
# 2009            Wii          0.636831
# 2010            Wii          0.506575
# 2011            Wii          0.409521
# 2012            Wii          0.716875
# 2013            Wii          0.715833
# 2014            Wii          0.625000
# 2015            Wii          0.285000
# 2016            Wii          0.180000

# %% [markdown]
# ##### Вывод:
# Провальные игры были выпущены для платформы DC.
# Популярные игры были выпущены для платформы Wii.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b></b>
# Разница между платформами формируется из-за времени жизни платформы или популярности других плафторм.
# </div>

# %% [markdown]
# ##### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.<a name="3.5"></a>

# %% [markdown]
# #####  Популярная платформа:

# %%
data_XOne=data.query('platform == "XOne" and critic_score!=0 and user_score!=-1 and user_score!=-2')

# %%
len(data_XOne['critic_score'])
# Out:
# 165

# %%
g = sns.FacetGrid(data_XOne, size=8)
g.map(plt.scatter, "critic_score", "total_sales")#,alpha=0.03)

# %%
g = sns.FacetGrid(data_XOne, size=8)
g.map(plt.scatter, "user_score", "total_sales")#,alpha=0.03)

# %%
len(data_XOne['user_score'])
# Out:
# 165

# %%
cor_critic=data_XOne['critic_score'].corr(data_XOne['total_sales'])

# %%
print(cor_critic)
# Out:
# 0.41042203561296375

# %%
cor_user=data_XOne['user_score'].corr(data_XOne['total_sales'])

# %%
print(cor_user)
# Out:
# -0.09400318326920852

# %%
data_PSV=data.query('platform == "PSV" and critic_score!=0 and user_score!=-1 and user_score!=-2')

# %%
display(data_PSV)
# Out:
#                                        name platform  year_of_release  \
# 1218                Uncharted: Golden Abyss      PSV             2011
# 1293   Call of Duty Black Ops: Declassified      PSV             2012
# 1484       Assassin's Creed III: Liberation      PSV             2012
# 1594                LittleBigPlanet PS Vita      PSV             2012
# 1830                      Persona 4: Golden      PSV             2012
# ...                                     ...      ...              ...
# 15196      Psycho-Pass: Mandatory Happiness      PSV             2016
# 15510           Dynasty Warriors 8: Empires      PSV             2015
# 16258           htoL#NiQ: The Firefly Diary      PSV             2014
# 16271                    Doki-Doki Universe      PSV             2013
# 16372                                Dokuro      PSV             2012
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
len(data_PSV['critic_score'])
# Out:
# 119

# %%
g = sns.FacetGrid(data_PSV, size=8)
g.map(plt.scatter, "critic_score", "total_sales")#,alpha=0.03)

# %%
len(data_PSV['user_score'])
# Out:
# 119

# %%
g = sns.FacetGrid(data_PSV, size=8)
g.map(plt.scatter, "user_score", "total_sales")#,alpha=0.03)

# %%
cor_critic=data_PSV['critic_score'].corr(data_PSV['total_sales'])

# %%
display(cor_critic)
# Out:
# 0.13134877792387234

# %%
cor_user=data_PSV['user_score'].corr(data_PSV['total_sales'])

# %%
display(cor_user)
# Out:
# 0.03837423933414698

# %% [markdown]
# ##### Вывод:
# Исходя из диаграммы рассеяния и коэффициентов корреляции, можно сделать вывод, что для XOne существует слабая линейная взаимосвязь между продажами и оценкой критиков и очень слабая между продажами и оценками игроков, в то время, как для платформы PSV существует слабая линейная взаимосвязь между продажами и оценкой критиков и очень слабая между продажами и оценками игроков.  Но стоит заметить, что разброс пользовательских оценок для PSV меньше, чем для XOne : обратная сторона популярности)))

# %% [markdown]
# ##### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами? <a name="3.6"></a>

# %%
sales_by_genres=data.pivot_table(index='genre',values='total_sales',aggfunc='sum')

# %%
sales_by_genres=sales_by_genres.sort_values(by=['total_sales'],ascending=False)

# %%
sales_by_genres.reset_index(inplace=True)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('genre')
plt.ylabel('total_sales')
sns.barplot(y='total_sales',x='genre',data=sales_by_genres).set_title("Sales by genres")
plt.xticks(sales_by_genres.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Вывод:
# Самыми прибыльными жанрами являются "Action","Sports","Shooter".
# Самые низкие продажи у "Puzzle","Adventure","Strategy".
# Самые низкие продажи у жанров, которые требуют максимальной концентрации.

# %% [markdown]
# ## Шаг 4. Портреты пользователя каждого региона <a name="step4"></a>

# %% [markdown]
# ##### 4.1.Самые популярные платформы (топ-5) по регионам. <a name="4.1"></a>

# %%
# создам сводную таблицу по платформам, регионам и продажам
region_sales = data.pivot_table(index='platform',values=['na_sales', 'eu_sales', 'jp_sales', 'total_sales'],aggfunc='sum').reset_index()

# %%
# создам новые столбцы в сводной табличке для европейского, японского и североамериканского региона
region_sales['eu_rate'] = region_sales['eu_sales'] / region_sales['total_sales']
region_sales['jp_rate'] = region_sales['jp_sales'] / region_sales['total_sales']
region_sales['na_rate'] = region_sales['na_sales'] / region_sales['total_sales']

# %%
region_sales.head(5)
# Out:
#   platform  eu_sales  jp_sales  na_sales  total_sales   eu_rate   jp_rate  \
# 0     2600      5.47      0.00     90.60        96.98  0.056403  0.000000
# 1      3DO      0.00      0.10      0.00         0.10  0.000000  1.000000
# 2      3DS     61.48    100.67     83.49       259.00  0.237375  0.388687
# 3       DC      1.69      8.56      5.43        15.95  0.105956  0.536677
# 4       DS    188.89    175.57    382.40       806.12  0.234320  0.217796
#
#     na_rate
# 0  0.934213
# 1  0.000000
# 2  0.322355
# 3  0.340439
# 4  0.474371

# %%
# сводная таблица для европейского региона
region_eu=region_sales.pivot_table(index='platform',values=['eu_sales','eu_rate'],aggfunc='sum').sort_values(by='eu_sales', ascending=False)

# %%
text='ТОП 5 Европа'
x=text.center(25)
print(' ')
print(x)
display(region_eu.head(5))
# Out:
#
#        ТОП 5 Европа
#            eu_rate  eu_sales
# platform
# PS2       0.270185    339.29
# PS3       0.351503    330.29
# X360      0.278726    270.76
# Wii       0.288933    262.21
# PS        0.292272    213.61

# %%
region_eu=region_eu.head(5)

# %%
region_eu=region_eu.reset_index()

# %%
print(region_eu.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_eu, x='eu_sales', y='platform', palette="bone").set_title("Top-5 Europe")
plt.yticks(region_eu.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод:
# Для европейского региона популярными платформами являются PS2 (Sony), PS3(Sony), X360(Microsoft), Wii(Nintendo), PS(Sony).

# %%
# создам сводную таблицу для японского региона 
region_jp=region_sales.pivot_table(index='platform',values=['jp_sales','jp_rate'],aggfunc='sum').sort_values(by='jp_sales', ascending=False)

# %%
text='ТОП 5 Япония'
x=text.center(25)
print(' ')
print(x)
display(region_jp.head(5))
# Out:
#
#        ТОП 5 Япония
#            jp_rate  jp_sales
# platform
# DS        0.217796    175.57
# PS        0.191309    139.82
# PS2       0.110848    139.20
# SNES      0.582633    116.55
# 3DS       0.388687    100.67

# %%
region_jp=region_jp.head(5).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_jp, x='jp_sales', y='platform', palette="bone").set_title("Top-5 Japan")
plt.yticks(region_jp.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод :
# Для японского региона популярными платформами являются DS(Nintendo), PS(Sony), PS2(Sony), SNES(NINTENDO) и 3DS(NINTENDO).    Платформы японского происхождения: 5/5.

# %%
# создам сводную таблицу для североамериканского региона
region_na=region_sales.pivot_table(index='platform',values=['na_sales','na_rate'],aggfunc='sum').sort_values(by='na_sales', ascending=False)

# %%
text='ТОП 5 Северная Америка'
x=text.center(25)
print(' ')
print(x)
display(region_na.head(5))
# Out:
#
#   ТОП 5 Северная Америка
#            na_rate  na_sales
# platform
# X360      0.620195    602.47
# PS2       0.464926    583.84
# Wii       0.547542    496.90
# PS3       0.418762    393.49
# DS        0.474371    382.40

# %%
region_na=region_na.head(5).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_na, x='na_sales', y='platform', palette="bone").set_title("Top-5 Notrh America")
plt.yticks(region_na.index, rotation=75, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод :
# Для североамериканского региона популярными платформами являются X360(Microsoft), PS2(Sony), Wii(Nintendo), PS3(Sony), DS(Nintendo).

# %% [markdown]
# ##### Общий вывод
# Для трех регионов определены общие фавориты по продажам PS2 японского происхождения компании Sony.
# Европейский регион характеризуется подвляющим большинством платформ японского происхождения.
# Японский регион характеризуется только платформами японского происхождения.
# А североамериканский регион характеризуется платформами японского происхождения и американского.
# Похоже, что Япония захватила мир)

# %% [markdown]
# ##### 4.2.Самые популярные жанры (топ-5). <a name="4.2"></a>

# %%
region_genre = data.pivot_table(index='genre',values=['na_sales', 'eu_sales', 'jp_sales', 'total_sales'],aggfunc='sum').reset_index()

# %%
region_genre['eu_rate'] = region_genre['eu_sales'] / region_genre['total_sales']
region_genre['jp_rate'] = region_genre['jp_sales'] / region_genre['total_sales']
region_genre['na_rate'] = region_genre['na_sales'] / region_genre['total_sales']

# %%
region_genre_eu=region_genre.pivot_table(index='genre',values=['eu_sales','eu_rate'],aggfunc='sum').sort_values(by='eu_sales', ascending=False)

# %%
text='ТОП 5 Европа'
x=text.center(25)
print(' ')
print(x)
display(region_genre_eu.head(5))
# Out:
#
#        ТОП 5 Европа
#           eu_rate  eu_sales
# genre
# Action   0.297637    519.13
# Sports   0.283030    376.79
# Shooter  0.301525    317.34
# Racing   0.324578    236.51
# Misc     0.265093    212.74

# %%
region_genre_eu=region_genre_eu.head(5).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_genre_eu, x='eu_sales', y='genre', palette="Oranges_r").set_title("Top-5 Europe")
plt.yticks(region_genre_eu.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод.
# Для европейского региона популярными жанрами являются Action, Sports, Shooter, Racing, Misc	.

# %%
region_genre_jp=region_genre.pivot_table(index='genre',values=['jp_sales','jp_rate'],aggfunc='sum').sort_values(by='jp_sales', ascending=False)

# %%
text='ТОП 5 Япония'
x=text.center(25)
print(' ')
print(x)
display(region_genre_jp.head(5))
# Out:
#
#        ТОП 5 Япония
#                jp_rate  jp_sales
# genre
# Role-Playing  0.380297    355.41
# Action        0.092554    161.43
# Sports        0.101813    135.54
# Platform      0.158051    130.83
# Misc          0.134715    108.11

# %%
region_genre_jp=region_genre_jp.head(5).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_genre_jp, x='jp_sales', y='genre', palette="Oranges_r").set_title("Top-5 Japan")
plt.yticks(region_genre_jp.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод
# Для японского региона популярными жанрами являются Role-Playing, Action, Sports, Platform, Misc

# %%
region_genre_na=region_genre.pivot_table(index='genre',values=['na_sales','na_rate'],aggfunc='sum').sort_values(by='na_sales', ascending=False)

# %%
text='ТОП 5 Северная Америка'
x=text.center(25)
print(' ')
print(x)
display(region_genre_na.head(5))
# Out:
#
#   ТОП 5 Северная Америка
#            na_rate  na_sales
# genre
# Action    0.503970    879.01
# Sports    0.514118    684.43
# Shooter   0.562725    592.24
# Platform  0.538193    445.50
# Misc      0.507495    407.27

# %%
region_genre_na=region_genre_na.head(5).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_genre_na, x='na_sales', y='genre', palette="Oranges_r").set_title("Top-5 Notrh America")
plt.yticks(region_genre_na.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод.
# Для североамериканского региона популярными жанрами являются Action, Sports, Shooter, Platform, Misc

# %% [markdown]
# ##### Общий вывод.
# Для всех регионов лидер по жанрам: жанр Action,Sports,Misc.

# %% [markdown]
# ##### 4.3.Влияет ли рейтинг ESRB на продажи в отдельном регионе?<a name="4.3"></a>

# %%
region_rating = data.pivot_table(index='rating',values=['na_sales', 'eu_sales', 'jp_sales', 'total_sales'],aggfunc='sum').reset_index()

# %%
region_rating['eu_rate'] = region_rating['eu_sales'] / region_rating['total_sales']
region_rating['jp_rate'] = region_rating['jp_sales'] / region_rating['total_sales']
region_rating['na_rate'] = region_rating['na_sales'] / region_rating['total_sales']

# %%
region_rating_eu=region_rating.pivot_table(index='rating',values=['eu_sales','eu_rate'],aggfunc='sum').sort_values(by='eu_sales', ascending=False)

# %%
text='Европа рейтинг'
x=text.center(25)
print(' ')
print(x)
display(region_rating_eu.head(8))
# Out:
#
#       Европа рейтинг
#             eu_rate  eu_sales
# rating
# E          0.291216    710.52
# no rating  0.215427    613.30
# M          0.328385    483.97
# T          0.285954    427.03
# E10+       0.287553    188.52
# AO         0.311224      0.61
# EC         0.062857      0.11
# RP         0.888889      0.08

# %%
region_rating_eu=region_rating_eu.head(7).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_rating_eu, x='eu_sales', y='rating', palette="Blues").set_title("Europe rating")
plt.yticks(region_rating_eu.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# Рассмотрю поближе график

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlim(0,10)
sns.barplot(data=region_rating_eu, x='eu_sales', y='rating', palette="Blues").set_title("Europe rating")
plt.yticks(region_rating_eu.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод:
# для европейского региона:
# 1. E (для всех,от 6 лет и старше)
# 2. no rating(рейтинг отсутствует)
# 3. M (для взрослых, от 17 лет и старше)
# 4. T (подросткам от 13 лет и старше)
# 5. E10+ (для всех от 10 лет и старше)
# 6. AO (только для взрослых)
# 7. EC (для детей младшего возраста)
# 8. RP (рейтинг ожидается )
# Самым популярным рейтингом является рейтинг "для всех,от 6 лет и старше".
# Самым непопулярным рейтингом является рейтинг "для детей младшего возраста".
# Совсем мало игр с рейтингом "рейтинг ожидается".
# Можно утверждать, что так как ограничения на игры нет, такие игры в данном регионе самые продаваемые.

# %%
region_rating_jp=region_rating.pivot_table(index='rating',values=['jp_sales','jp_rate'],aggfunc='sum').sort_values(by='jp_sales', ascending=False)

# %%
text='Япония рейтинг'
x=text.center(25)
print(' ')
print(x)
display(region_rating_jp.head(7))
# Out:
#
#       Япония рейтинг
#             jp_rate  jp_sales
# rating
# no rating  0.295735    841.93
# E          0.081796    199.57
# T          0.101383    151.40
# M          0.043588     64.24
# E10+       0.061318     40.20
# AO         0.000000      0.00
# EC         0.000000      0.00

# %%
region_rating_jp=region_rating_jp.head(7).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlabel('year_of_release')
plt.ylabel('total_sales')
sns.barplot(data=region_rating_jp, x='jp_sales', y='rating', palette="Blues").set_title("Japan rating")
plt.yticks(region_rating_jp.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод:
# для японского региона:
# 1. no rating (рейтинг отсутствует)
# 2. E(для всех,от 6 лет и старше)
# 3. T(подросткам от 13 лет и старше)
# 4. M(для взрослых, от 17 лет и старше)
# 5. E10+(для всех от 10 лет и старше)
# Самым популярным рейтингом является рейтинг "no rating".
# Нет игр с рейтингом "AO","EC","RP".

# %%
region_rating_na=region_rating.pivot_table(index='rating',values=['na_sales','na_rate'],aggfunc='sum').sort_values(by='na_sales', ascending=False)

# %%
text='Северная Америка рейтинг'
x=text.center(25)
print(' ')
print(x)
display(region_rating_na.head(7))
# Out:
#
#  Северная Америка рейтинг
#             na_rate  na_sales
# rating
# E          0.530998   1295.55
# no rating  0.435799   1240.68
# T          0.508755    759.75
# M          0.507861    748.48
# E10+       0.538926    353.32
# EC         0.874286      1.53
# AO         0.642857      1.26

# %%
region_rating_na=region_rating_na.head(7).reset_index()

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(data=region_rating_na, x='na_sales', y='rating', palette="Blues").set_title("Notrh America rating")
plt.yticks(region_rating_na.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# Рассмотрю поближе график

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.xlim(0,10)
sns.barplot(data=region_rating_na, x='na_sales', y='rating', palette="Blues").set_title("Notrh America rating")
plt.yticks(region_rating_na.index, rotation=55, fontsize=15)
ax.grid=True

# %% [markdown]
# ##### Промежуточный вывод:
# для североамериканского региона:
# 1. E(для всех,от 6 лет и старше)
# 2. no rating (рейтинг отсутствует)
# 3. T(подросткам от 13 лет и старше)
# 4. M(для взрослых, от 17 лет и старше)
# 5. E10+(для всех от 10 лет и старше)
# 6. EC(для детей младшего возраста)
# 7. AO(только для взрослых)
# Самым популярным рейтингом является рейтинг "для всех,  от 6 лет и старше".
# Регион, котором нет рейтинга "рейтинг ожидается".

# %%
region_rating
# Out:
#       rating  eu_sales  jp_sales  na_sales  total_sales   eu_rate   jp_rate  \
# 0         AO      0.61      0.00      1.26         1.96  0.311224  0.000000
# 1          E    710.52    199.57   1295.55      2439.84  0.291216  0.081796
# 2       E10+    188.52     40.20    353.32       655.60  0.287553  0.061318
# 3         EC      0.11      0.00      1.53         1.75  0.062857  0.000000
# 4          M    483.97     64.24    748.48      1473.79  0.328385  0.043588
# 5         RP      0.08      0.00      0.00         0.09  0.888889  0.000000
# 6          T    427.03    151.40    759.75      1493.35  0.285954  0.101383
# 7  no rating    613.30    841.93   1240.68      2846.91  0.215427  0.295735
#
#     na_rate
# 0  0.642857
# 1  0.530998
# 2  0.538926
# 3  0.874286
# 4  0.507861
# 5  0.000000
# 6  0.508755
# 7  0.435799

# %% [markdown]
# ##### Общий вывод:
# Для европейского и североамериканского региона популярный рейтинг: "для всех, от 6 лет и старше",  а для японского "no rating".
#
# Непопулярные рейтинги:
# * европейский регион:"рейтинг ожидается"
# * японский регион: "для всех, от 10 лет и старше"
# * североамериканский регион: "рейтинг ожидается"
#
# Отстутствуют рейтинги:
#
# * европейский регион: -
# * японский регион:"для детей младшего возраста","только для взрослых","рейтинг ожидается"
# * североамериканский регион: "только для взрослых"
#
# Рейтинг ESRB влияет на продажи игр, так как игры с ограничением по возрастному прзнаку не были в топе.

# %% [markdown]
# ## Шаг 5. Проверка гипотез <a name="step5"></a>

# %% [markdown]
# ##### 5.1. Гипотеза: 'средние пользовательские рейтинги платформ Xbox One и PC одинаковые'<a name="h_1"></a>

# %% [markdown]
# Буду использовать t-критерий Стьюдента, потому что сравниваемые выборки независимы между собой.
# Сформулирую нулевую гипотезу H₀ и альтернативную гипотезу H₁.
#
# H₀ всегда формулируется так, чтобы использовать знак равенства.
# H₀: средние пользовательские рейтинги платформ Xbox One и PC не различаются
# H₁: средние пользовательские рейтинги платформ Xbox One и PC различаются

# %%
#срез по платформе XOne и по существеющим пользовательским рейтингам
XOne=data.query('platform=="XOne" and user_score!=-1 and user_score!=-2')

# %%
display(XOne.head(10))
# Out:
#                                   name platform  year_of_release  \
# 165                 Grand Theft Auto V     XOne             2014
# 179     Call of Duty: Advanced Warfare     XOne             2014
# 242                  Halo 5: Guardians     XOne             2015
# 270                          Fallout 4     XOne             2015
# 373            Assassin's Creed: Unity     XOne             2014
# 398                            Destiny     XOne             2014
# 413     Gears of War: Ultimate Edition     XOne             2015
# 417                            FIFA 16     XOne             2015
# 422  Halo: The Master Chief Collection     XOne             2014
# 484                          Titanfall     XOne             2014
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 165        Action      2.81      2.19      0.00         0.47          97.0
# 179       Shooter      3.22      1.55      0.01         0.48          81.0
# ...

# %%
#срез по платформе PC и по существеющим пользовательским рейтингам
PC=data.query('platform=="PC" and user_score!=-1 and user_score!=-2')

# %%
display(PC.head(10))
# Out:
#                                        name platform  year_of_release  \
# 85                               The Sims 3       PC             2009
# 138                       World of Warcraft       PC             2004
# 192                              Diablo III       PC             2012
# 218          StarCraft II: Wings of Liberty       PC             2010
# 284                               Half-Life       PC             1997
# 288  World of Warcraft: The Burning Crusade       PC             2007
# 313             The Elder Scrolls V: Skyrim       PC             2011
# 330                     The Sims: Unleashed       PC             2002
# 455                      The Sims: Vacation       PC             2002
# 458                              The Sims 4       PC             2014
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 85     Simulation      0.99      6.42      0.00         0.60          86.0
# ...

# %%
print('Количество пользовательских рейтингов для PC:', len(XOne))
print('Количество пользовательских рейтингов для XBox One:', len(PC))
# Out:
# Количество пользовательских рейтингов для PC: 182
# Количество пользовательских рейтингов для XBox One: 770

# %% [markdown]
# Сравню дисперсии. Если дисперсии различаются, следовательно можно воспользоваться параметром equal_var = False.

# %%
XOne_var=np.var(XOne['user_score'],ddof=1)
print(XOne_var)
# Out:
# 1.9069968429360702

# %%
PC_var=np.var(PC['user_score'],ddof=1)
print(PC_var)
# Out:
# 2.3407871413372

# %% [markdown]
# Дисперсии различаются!

# %% [markdown]
# Пороговое значение alpha  задам равным 5%.

# %%
alpha = .05

results = st.ttest_ind(
    XOne['user_score'], 
    PC['user_score'],
    equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 4.935072360183565e-06
# Отвергаем нулевую гипотезу

# %% [markdown]
# ##### Вывод:
# Вероятность того, что нулевая гипотеза истинна, меньше порогового значения.
# Следовательно, можно отвергнуть нулевую гипотезу и утверждать, что средние пользовательские рейтинги платформ Xbox One и PC различаются.

# %% [markdown]
# ##### 5.2. Гипотеза: 'средние пользовательские рейтинги жанров Action и Sports  разные.' <a name="h_2"></a>

# %% [markdown]
# Буду использовать t-критерий Стьюдента, потому что сравниваемые выборки независимы между собой.
# Сформулирую нулевую гипотезу H₀ и альтернативную гипотезу H₁.
#
# H₀: средние пользовательские рейтинги жанров Action и Sports не различаются
# H₁: средние пользовательские рейтинги жанров Action и Sports различаются

# %%
#срез по жанру Action и по существеющим пользовательским рейтингам
Action=data.query('genre=="Action" and user_score!=-1 and user_score!=-2')

# %%
display(Action.head(10))
# Out:
#                                       name platform  year_of_release   genre  \
# 16                      Grand Theft Auto V      PS3             2013  Action
# 17           Grand Theft Auto: San Andreas      PS2             2004  Action
# 23                      Grand Theft Auto V     X360             2013  Action
# 24             Grand Theft Auto: Vice City      PS2             2002  Action
# 38                    Grand Theft Auto III      PS2             2001  Action
# 42                      Grand Theft Auto V      PS4             2014  Action
# 51                     Grand Theft Auto IV     X360             2008  Action
# 57                     Grand Theft Auto IV      PS3             2008  Action
# 81                          FIFA Soccer 13      PS3             2012  Action
# 91  Grand Theft Auto: Liberty City Stories      PSP             2005  Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %%
#срез по жанру Sports и по существеющим пользовательским рейтингам
Sports=data.query('genre=="Sports" and user_score!=-1 and user_score!=-2')

# %%
display(Sports.head(10))
# Out:
#                   name platform  year_of_release   genre  na_sales  eu_sales  \
# 0           Wii Sports      Wii             2006  Sports     41.36     28.96
# 3    Wii Sports Resort      Wii             2009  Sports     15.61     10.93
# 13             Wii Fit      Wii             2007  Sports      8.92      8.03
# 15        Wii Fit Plus      Wii             2009  Sports      9.01      8.49
# 77             FIFA 16      PS4             2015  Sports      1.12      6.12
# 94             FIFA 17      PS4             2016  Sports      0.66      5.75
# 126            FIFA 14      PS3             2013  Sports      0.78      4.24
# 141      Kinect Sports     X360             2010  Sports      3.92      1.73
# 143            FIFA 15      PS4             2014  Sports      0.80      4.33
# 183    Madden NFL 2004      PS2             2003  Sports      4.26      0.26
#
#      jp_sales  other_sales  critic_score  user_score rating  total_sales
# ...

# %%
print('Количество пользовательских рейтингов для жанра Action:', len(Action))
print('Количество пользовательских рейтингов для жанра Sports:', len(Sports))
# Out:
# Количество пользовательских рейтингов для жанра Action: 1830
# Количество пользовательских рейтингов для жанра Sports: 1103

# %% [markdown]
# Сравню дисперсии. Если дисперсии различаются, следовательно можно воспользоваться параметром equal_var = False.

# %%
Action_var=np.var(Action['user_score'],ddof=1)
print(Action_var)
# Out:
# 2.031746898033191

# %%
Sports_var=np.var(Sports['user_score'],ddof=1)
print(Sports_var)
# Out:
# 2.5965147189730073

# %% [markdown]
# Дисперсии различаются!

# %% [markdown]
# Пороговое значение alpha  задам равным 1%.

# %%
alpha = .01

results = st.ttest_ind(
    Action['user_score'], 
    Sports['user_score'],
    equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.11483818791498286
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ##### Вывод:
# Так как вероятность истинности равна 11% можно утверждать, что мы не можем отвергнуть нулевую гипотезу.

# %% [markdown]
# ## Шаг 6. Общий вывод <a name="step6"></a>

# %% [markdown]
# **Шаг 1.**
#
# Таблица 1. Пропущенные значения
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.31.14.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.31.14.png)
#
#
# Таблица 2. Найденные проблемы в признаках
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.31.44.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.31.44.png)
#
# Таблица 3. Рейтинг игр ESRB (Entertainment Software Rating Board)
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.40.02.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.40.02.png)

# %% [markdown]
# **Шаг 2.**
# Таблица 4. Исправленные проблемы в признаках
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.36.19.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.36.19.png)
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.36.30.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-05-20%20%D0%B2%2016.36.30.png)

# %% [markdown]
# **Шаг 3**
# 3.1.Нахождение количества игр по разным годам
#    - на данном шаге было построено распределние количества игр по разным годам с помощью сводных таблиц
#    - максимальное количество игр было выпущено в 2008 году
#
# 3.2.Построение распределения продаж по платформам
#    - на данном шаге было построены распределения продаж по семи популярным платформам PS2,X360,PS3,Wii,DS,PS,GBA
#    - максимальные продажи были у платформы PS2
#    - c 1994 года заметен рост количества выпущенных игр, проверю во сколько раз выпущенных игр больше в 1994 году, чем в 1993 году
#    - время существования платформы примерно 11 лет
#
# 3.3. Построение распределения продаж по платформам за актуальный период
#    - были построеня распределения продаж по платформам за актуальный период
#    - по графикам было замечено, что наиболее прибыльными платформами для 2017 года будут следующие: XOne, PS4. У остальных платформ к 2017 году продажи падают
#
# 3.4.Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#    - все года: провальные игры были выпущены для платформы DC, популярные игры были выпущены для платформы Wii.
#    - актуальный период: провальные игры были выпущены для платформы PCFX,популярные игры были выпущены для платформы Wii.
#
# 3.5.Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#
#    - исходя из диаграммы рассеяния и коэффициентов корреляции, можно сделать вывод, что для XOne существует слабая линейная взаимосвязь между продажами и оценкой критиков и очень слабая между продажами и оценками игроков, в то время, как для платформы PSV существует слабая линейная взаимосвязь между продажами и оценкой критиков и очень слабая между продажами и оценками игроков.  Но стоит заметить, что разброс пользовательских оценок для PSV меньше, чем для XOne : обратная сторона популярности)))
#
# 3.6.Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# - Самыми прибыльными жанрами являются "Action","Sports","Shooter".
# - Самые низкие продажи у "Puzzle","Adventure","Strategy".
# - Самые низкие продажи у жанров, которые требуют максимальной концентрации.

# %% [markdown]
# ##### Шаг 4. Портреты пользователя каждого региона
# * 4.1.Самые популярные платформы (топ-5).
#   - Для европейского региона популярными платформами являются PS2 (Sony), PS3(Sony), X360(Microsoft), Wii(Nintendo), PS(Sony).
#   - Для японского региона популярными платформами являются DS(Nintendo), PS(Sony), PS2(Sony), SNES(NINTENDO) и 3DS(NINTENDO). Платформы японского происхождения: 5/5.
#   - Для североамериканского региона популярными платформами являются X360(Microsoft), PS2(Sony), Wii(Nintendo), PS3(Sony), DS(Nintendo).
#
#
# **Вывод:**
# Для трех регионов определены общие фавориты по продажам PS2 японского происхождения компании Sony.
# Европейский регион характеризуется подвляющим большинством платформ японского происхождения.
# Японский регион характеризуется только платформами японского происхождения.
# А североамериканский регион характеризуется платформами японского происхождения и американского.
# Похоже, что Япония захватила мир)
#
# * 4.2.Самые популярные жанры (топ-5).
#     - Для европейского региона популярными жанрами являются Action, Sports, Shooter, Racing, Misc
#     - Для японского региона популярными жанрами являются Role-Playing, Action, Sports, Platform, Misc
#     - Для североамериканского региона популярными жанрами являются Action, Sports, Shooter, Platform, Misc
#
# **Вывод:**
# Для всех регионов лидер по жанрам: жанр Action,Sports,Misc.
#
# * 4.3.Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#  Для европейского и североамериканского региона популярный рейтинг: "для всех, от 6 лет и старше", для японского: "no rating".
#
# Непопулярные рейтинги:
# * европейский регион:"рейтинг ожидается"
# * японский регион: "для всех, от 10 лет и старше"
# * североамериканский регион: "рейтинг ожидается"
#
# Отстутствуют рейтинги:
#
# * европейский регион: -
# * японский регион:"для детей младшего возраста","только для взрослых","рейтинг ожидается"
# * североамериканский регион: "только для взрослых"
#
#
# **Вывод:**
# Рейтинг ESRB влияет на продажи игр, так как игры с ограничением по возрастному прзнаку не были в топе.

# %% [markdown]
# ##### Шаг 5. Проверка гипотез
# * 5.1. Гипотеза: 'средние пользовательские рейтинги платформ Xbox One и PC одинаковые'
#
# Были сформулированы следующие гипотезы:
# H₀: средние пользовательские рейтинги платформ Xbox One и PC не различаются
# H₁: средние пользовательские рейтинги платформ Xbox One и PC различаются
# Вероятность того, что нулевая гипотеза истинна, меньше порогового значения.
# Следовательно, можно отвергнуть нулевую гипотезу и утверждать, что средние пользовательские рейтинги платформ Xbox One и PC различаются.
#
# * 5.2. Гипотеза: 'средние пользовательские рейтинги жанров Action  и Sports разные.'
#
# Были сформулированы следующие гипотезы:
# H₀: средние пользовательские рейтинги жанров Action и Sports не различаются
# H₁: средние пользовательские рейтинги жанров Action и Sports различаются
# Так как вероятность истинности равна 11% можно утверждать, что мы не можем отвергнуть нулевую гипотезу.
